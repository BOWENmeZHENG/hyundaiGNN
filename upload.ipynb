# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/research/Hyundai/codes
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/research/Hyundai/codes

# %%
# !gcloud auth login
# Out:
# Go to the following link in your browser, and complete the sign-in prompts:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=32555940559.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fsdk.cloud.google.com%2Fauthcode.html&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fappengine.admin+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcompute+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth&state=Tc19qE9LICHpJH1fyi01vxC5FqF0KK&prompt=consent&token_usage=remote&access_type=offline&code_challenge=pxAhqiNpdfZnakNIeZ_DfFWIzSsurwxhY6CAdD1PA6E&code_challenge_method=S256
#
# Once finished, enter the verification code provided in your browser: 4/0ASVgi3J6Z6Io2s0FIJGwgnn8fiOOfqzCFWnUcdiZDong8DALg1cZosF9NUSGN_YZXwUFGg
#
# You are now logged in as [bowen_zheng@berkeley.edu].
# ...

# %%
# !gcloud config set project hyundai-449923

# %%
# !gsutil cp run_new.py trainer.py utils.py net.py gs://hyundai-code-data/code/
# Out:
# Copying file://run_new.py [Content-Type=text/x-python]...
# Copying file://trainer.py [Content-Type=text/x-python]...
# Copying file://utils.py [Content-Type=text/x-python]...
# Copying file://net.py [Content-Type=text/x-python]...
# |
# Operation completed over 4 objects/24.4 KiB.
