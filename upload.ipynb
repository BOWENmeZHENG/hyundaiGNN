# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/research/Hyundai/codes
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/research/Hyundai/codes

# %%
# !gcloud auth login
# Out:
# Go to the following link in your browser, and complete the sign-in prompts:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=32555940559.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fsdk.cloud.google.com%2Fauthcode.html&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fappengine.admin+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcompute+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth&state=rKAf29b2pITVEDXNE7CJ78cMNvox5K&prompt=consent&token_usage=remote&access_type=offline&code_challenge=PedSBMvmTIisUUJR73xUENAI7mdJ19MDtLNRAI5Uh5Q&code_challenge_method=S256
#
# Once finished, enter the verification code provided in your browser: 4/0ASVgi3J2w9iK12JE2uHqi8KZHVJcd_B4RkzLAd4SUV1A0T20A72phJ0wf71gaPI_EqnWdA
#
# You are now logged in as [bowen_zheng@berkeley.edu].
# Your current project is [hyundai-449923].  You can change this setting by running:
#   $ gcloud config set project PROJECT_ID

# %%
# !gcloud config set project hyundai-449923
# Out:
# Updated property [core/project].

# %%
# !gsutil cp run.py trainer.py utils.py net.py gs://hyundai-code-data/code/
# Out:
# Copying file://run.py [Content-Type=text/x-python]...
# Copying file://trainer.py [Content-Type=text/x-python]...
# Copying file://utils.py [Content-Type=text/x-python]...
# Copying file://net.py [Content-Type=text/x-python]...
# /
# Operation completed over 4 objects/20.2 KiB.
